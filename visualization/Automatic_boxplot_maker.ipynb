# %% [markdown]
# ## Automatic boxplot maker

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(font_scale=1.3)

# %% [markdown]
# ---
# ## 전체 boxplot

# %%
dfs = ['GSE60926', 'GSE28460', 'GSE13576', 'TARGET']
for k in dfs:
    table = pd.read_csv('./%s.csv' %k)
    
    smc2 = []
    smc4 = []
    tpd53 = []
    capd2 = []
    capg = []
    caph = []
    capg2 = []
    caph2 = []
    capd3 = []

    gene = [smc2, smc4, tpd53, capd2, capg, caph, capg2, caph2, capd3]
    name = ['smc2', 'smc4', 'tpd53', 'capd2', 'capg', 'caph', 'capg2', 'caph2', 'capd3']

    for i in range(0, len(gene)):
        dia = table['name'] == ('%s_diagnosis' %name[i].upper())
        rel = table['name'] == ('%s_relapse' %name[i].upper())
        gene[i] = table[dia].append(table[rel])
        
    for i in range(0,len(gene)):
        plt.subplots(figsize = (3, 3))

        f1 = sns.boxplot(data=gene[i], x = gene[i]['name'], y = gene[i]['value'], color="0.8")
        #f1.set_ylim(0, max(max(smc2['value']),max(smc4['value']))+100)
        f1.set_title('%s' %k)
        sns.stripplot(data=gene[i], x = gene[i]['name'], y = gene[i]['value'], jitter=True, alpha=0.5)
        plt.xticks(rotation=90)

        plt.savefig('./%s_%s.png' %(k, name[i]), dpi=300, bbox_inches='tight')

# %%
table.head()
# Out:
#              name     value
# 0  SMC2_diagnosis  336.9405
# 1  SMC2_diagnosis  224.8930
# 2  SMC2_diagnosis  278.3947
# 3  SMC2_diagnosis  275.3193
# 4  SMC2_diagnosis  601.2498

# %% [markdown]
# ---
# ## 개별 plot

# %%
table = pd.read_csv('./GSE13576.csv')

smc2d = table['name'] == 'SMC2_diagnosis'
smc2r = table['name'] == 'SMC2_relapse'

smc4d = table['name'] == 'SMC4_diagnosis'
smc4r = table['name'] == 'SMC4_relapse'

smc2 = table[smc2d].append(table[smc2r])
smc4 = table[smc4d].append(table[smc4r])

# %%
plt.subplots(figsize = (3, 3))

f1 = sns.boxplot(data=smc2, x = smc2['name'], y = smc2['value'], color="0.8")
#f1.set_ylim(0, max(max(smc2['value']),max(smc4['value']))+100)
f1.set_title('GSE13576')
sns.stripplot(data=smc2, x = smc2['name'], y = smc2['value'], jitter=True, alpha=0.5)
plt.xticks(rotation=90)

plt.savefig('./GSE13576_smc2box.png', dpi=300, bbox_inches='tight')
