# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(font_scale=1.3)
from statannot import add_stat_annotation

# %%
dfs = ['GSE37168']
for k in dfs:
    table = pd.read_csv('./%s.csv' %k)
    
    tpd52 = []
    
    gene = [tpd52]
    name = ['TPD52_diagnosis','TPD52_relapse']

    for i in range(0, len(gene)):
        dia = table['name'] == ('%s' %name[i*2-1])
        rel = table['name'] == ('%s' %name[i*2])
        gene[i] = table[rel].append(table[dia])
        
    for i in range(0,len(gene)):
        plt.subplots(figsize = (3, 3))

        f1 = sns.boxplot(data=gene[i], x = gene[i]['name'], y = gene[i]['value'], color="0.8")
        #f1.set_ylim(0, max(max(smc2['value']),max(smc4['value']))+100)
        f1.set_title('%s' %k)
        sns.stripplot(data=gene[i], x = gene[i]['name'], y = gene[i]['value'], jitter=True, alpha=0.5)
        plt.xticks(rotation=90)
        
        add_stat_annotation(f1, data=gene[i], x = gene[i]['name'], y = gene[i]['value'],
                    box_pairs=[(("%s" %name[i*2-1]), ("%s" %name[i*2]))
                                ],
                    test='t-test_ind', text_format='star', loc='inside', verbose=2)

        plt.savefig('./%s.png' %(k), dpi=300, bbox_inches='tight')
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# TPD52_diagnosis v.s. TPD52_relapse: t-test independent samples, P_val=6.819e-03 stat=-2.921e+00

# %%
dfs = ['GSE107397']
for k in dfs:
    table = pd.read_csv('./%s.csv' %k)
    
    tpd52 = []
    
    gene = [tpd52]
    name = ['TPD52_alive in ongoing CR or PR','TPD52_death; relapse or progression;\r\nprimary treatment failure']

    for i in range(0, len(gene)):
        dia = table['name'] == ('%s' %name[i*2-1])
        rel = table['name'] == ('%s' %name[i*2])
        gene[i] = table[rel].append(table[dia])
        
    for i in range(0,len(gene)):
        plt.subplots(figsize = (3, 3))

        f1 = sns.boxplot(data=gene[i], x = gene[i]['name'], y = gene[i]['value'], color="0.8")
        #f1.set_ylim(0, max(max(smc2['value']),max(smc4['value']))+100)
        f1.set_title('%s' %k)
        sns.stripplot(data=gene[i], x = gene[i]['name'], y = gene[i]['value'], jitter=True, alpha=0.5)
        plt.xticks(rotation=90)
        
        add_stat_annotation(f1, data=gene[i], x = gene[i]['name'], y = gene[i]['value'],
                    box_pairs=[(("%s" %name[i*2-1]), ("%s" %name[i*2]))
                                ],
                    test='t-test_ind', text_format='star', loc='inside', verbose=2)

        plt.savefig('./%s.png' %(k), dpi=300, bbox_inches='tight')
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# TPD52_alive in ongoing CR or PR v.s. TPD52_death; relapse or progression;
# primary treatment failure: t-test independent samples, P_val=1.728e-02 stat=-2.463e+00

# %%
dfs = ['GSE6401']
for k in dfs:
    table = pd.read_csv('./%s.csv' %k)
    
    tpd52 = []
    
    gene = [tpd52]
    name = ['TPD52_stageI, II','TPD52_stageIII']

    for i in range(0, len(gene)):
        dia = table['name'] == ('%s' %name[i*2-1])
        rel = table['name'] == ('%s' %name[i*2])
        gene[i] = table[rel].append(table[dia])
        
    for i in range(0,len(gene)):
        plt.subplots(figsize = (3, 3))

        f1 = sns.boxplot(data=gene[i], x = gene[i]['name'], y = gene[i]['value'], color="0.8")
        #f1.set_ylim(0, max(max(smc2['value']),max(smc4['value']))+100)
        f1.set_title('%s' %k)
        sns.stripplot(data=gene[i], x = gene[i]['name'], y = gene[i]['value'], jitter=True, alpha=0.5)
        plt.xticks(rotation=90)
        
        add_stat_annotation(f1, data=gene[i], x = gene[i]['name'], y = gene[i]['value'],
                    box_pairs=[(("%s" %name[i*2-1]), ("%s" %name[i*2]))
                                ],
                    test='t-test_ind', text_format='star', loc='inside', verbose=2)

        plt.savefig('./%s.png' %(k), dpi=300, bbox_inches='tight')
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# TPD52_stageI, II v.s. TPD52_stageIII: t-test independent samples, P_val=3.896e-03 stat=-2.955e+00
